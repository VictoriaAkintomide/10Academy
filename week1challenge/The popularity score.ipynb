# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker

# %% [markdown]
# ### Importing the tweets of government officials in the past one year

# %%
presidents_tweets = pd.read_csv('tweets_of_presidents_one_year.csv')
presidents_tweets
# Out:
#               Created_date  Favorite_count  \
# 0      2020-07-15 16:52:14              28
# 1      2020-07-15 09:28:11               9
# 2      2020-07-15 09:28:10              11
# 3      2020-07-15 09:28:09               3
# 4      2020-07-15 09:28:08               4
# ...                    ...             ...
# 23089  2020-03-28 17:51:05              13
# 23090  2020-03-23 10:40:49              47
# 23091  2020-03-17 11:50:11               2
# 23092  2020-03-17 11:48:52              25
# 23093  2019-11-12 14:52:01              15
#
#                                           Hashtags  Retweet_count  \
# 0       [{'text': 'COVID19', 'indices': [57, 65]}]             13
# 1                                               []              2
# 2      [{'text': 'COVID19', 'indices': [95, 103]}]              2
# 3                                               []              0
# 4                                               []              0
# ...                                            ...            ...
# 23089                                           []             10
# 23090                                           []             16
# 23091                                           []              0
# 23092                                           []             17
# 23093                                           []              6
#
#                     Source                                              Tweet  \
# 0      Twitter for Android  b"Ministerial Statement: Minister of Health Li...
# 1          Twitter Web App  b'Ambassador Aragones: \xe2\x80\x9cWhen this p...
# 2          Twitter Web App  b'Ambassador Aragones: \xe2\x80\x9cThis assist...
# 3          Twitter Web App  b'PM: \xe2\x80\x9cThis support is significant ...
# 4          Twitter Web App  b'Prime Minister: \xe2\x80\x9cThe EU is showin...
# ...                    ...                                                ...
# 23089      Twitter Web App  b'Pour toute information sur coronavirus consu...
# 23090      Twitter Web App  b'Le premier cas confirm\xc3\xa9 de coronaviru...
# 23091      Twitter Web App                         b'https://t.co/QhnGix1V7f'
# 23092      Twitter Web App  b'Manifestations coronavirus https://t.co/mdjy...
# 23093      Twitter Web App  b"Mise \xc3\xa0 jour de la carte sanitaire, Kp...
#
#                   Tweet_ID User_Mentions         User_Name
# 0      1283444273149620224            []  @EswatiniGovern1
# 1      1283332522777157632            []  @EswatiniGovern1
# 2      1283332518964600839            []  @EswatiniGovern1
# 3      1283332516586422273            []  @EswatiniGovern1
# 4      1283332512966680578            []  @EswatiniGovern1
# ...                    ...           ...               ...
# 23089  1243958803453878273            []        @MSPS_Togo
# 23090  1242038584112185344            []        @MSPS_Togo
# 23091  1239881713922211840            []        @MSPS_Togo
# 23092  1239881384732344325            []        @MSPS_Togo
# 23093  1194266602520424454            []        @MSPS_Togo
#
# [23094 rows x 9 columns]

# %%
popularity = presidents_tweets[['User_Name','Favorite_count', 'Retweet_count']]
popular = popularity.groupby('User_Name', as_index=False)
popular

# %% [markdown]
# ### Calculating the popularity score

# %%
new_popular = popular.agg(np.sum)
new_popular['popularity_score'] = new_popular['Favorite_count'] + new_popular['Retweet_count'] 
new_popular = new_popular.sort_values('popularity_score', ascending=False).reset_index(drop=True)
new_popular
# Out:
#            User_Name  Favorite_count  Retweet_count  popularity_score
# 0           @MBuhari         1821119         489610           2310729
# 1     @SudanPMHamdok         1100303         238129           1338432
# 2    @KagutaMuseveni         1036126         185353           1221479
# 3        @NAkufoAddo          796905         138124            935029
# 4        @Macky_Sall          493056          80919            573975
# 5      @PresidencyZA          366911         181228            548139
# 6    @Presidence_RDC          446240          66825            513065
# 7   @StateHouseKenya          355183          90055            445238
# 8    @AOuattara_PRCI          287409          47985            335394
# 9        @PaulKagame          256174          57242            313416
# 10      @edmnangagwa          157467          46345            203812
# 11    @willynyamitwe           37350         161709            199059
# 12       @M_Farmaajo          133287          26981            160268
# 13          @hawelti           89495          40469            129964
# 14      @hagegeingob           82915          12433             95348
# 15     @rochkaborepf           74911          15238             90149
# 16  @CheikhGhazouani           63505           8111             71616
# 17   @PresidenceMali           52956          10728             63684
# 18      @IssoufouMhm           50721           8738             59459
# 19  @EswatiniGovern1           44109          13378             57487
# 20       @MinSantedj            3293          41486             44779
# 21     @PresidentBio           36251           6139             42390
# 22  @PresidenceBenin           20408          17257             37665
# 23        @Cherif_MZ           31614           3951             35565
# 24     @PresidentABO           23054           5349             28403
# 25   @Presidency_GMB           12724          13318             26042
# 26   @TZSpokesperson            7766          17071             24837
# 27       @MalawiGovt           15897           8095             23992
# 28        @mohzambia            1139          17498             18637
# 29         @USEmbalo           14582           2727             17309
# 30     @angola_Mirex            4440           1362              5802
# 31    @SouthSudanGov            1859           2541              4400
# 32     @President_GN             604            442              1046
# 33        @FinanceSC             123            625               748
# 34    @PresidenciaCV             162             74               236
# 35        @MSPS_Togo             129             73               202

# %% [markdown]
# ### Chart showing the top 10 popular officials

# %%
top_10_presidents_popular = new_popular[:10]
top_10_presidents_popular
with sns.axes_style("whitegrid"):
    ax = sns.barplot(x='User_Name', y='popularity_score', data=top_10_presidents_popular)
ax.yaxis.set_major_formatter(mticker.ScalarFormatter())
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
plt.xticks(rotation=90)
plt.title('Top 10 african government officials according to their popularity score')
plt.xlabel('African government officials')
plt.ylabel('Popularity Score')
plt.savefig('popularity_score.png', bbox_inches="tight", dpi=300)

# %% [markdown]
# ### Importing the tweets of the influencers for the past one year

# %%
influencers_tweets = pd.read_csv('tweets_of_influencers_one_year.csv')
influencers_tweets
# Out:
#                Created_date  Favorite_count Hashtags  Retweet_count  \
# 0       2020-07-13 19:41:02           20649       []           2730
# 1       2020-07-11 22:07:04               0       []          92777
# 2       2020-07-07 14:50:30           43315       []           5993
# 3       2020-07-06 21:54:14           14650       []           1635
# 4       2020-06-26 17:02:37               0       []            403
# ...                     ...             ...      ...            ...
# 123605  2019-07-14 15:36:11               5       []              0
# 123606  2019-07-14 03:26:42               0       []             26
# 123607  2019-07-11 02:53:05               4       []              0
# 123608  2019-07-11 02:52:19               0       []             23
# 123609  2019-07-08 10:43:40              12       []              2
#
#                     Source                                              Tweet  \
# 0                TweetDeck  b'Actual video footage of me starting off the ...
# 1          Twitter Web App           b'RT @KingBach: https://t.co/Sj2sVP7Gdt'
# 2          Twitter Web App  b'When white people take \xe2\x80\x9cbeing an ...
# 3          Twitter Web App  b'Me at the restaurant after things return to ...
# 4       Twitter for iPhone  b'RT @franklinleonard: \xe2\x80\x9cI have rape...
# ...                    ...                                                ...
# 123605  Twitter Web Client  b'\xe2\x80\x9cI don\xe2\x80\x99t know why I\xe...
# 123606  Twitter for iPhone  b'RT @scroll_in: Elephants in India are changi...
# 123607  Twitter Web Client  b'we should ALL do more burpees. https://t.co/...
# 123608  Twitter Web Client  b'RT @halbfinger: Liberal U.S. Jews complain t...
# 123609  Twitter Web Client  b'Sad topic. Amazing photo. https://t.co/vqAxw...
#
#                    Tweet_ID  \
# 0       1282761976343662593
# 1       1282073950843858944
# 2       1280514534155923459
# 3       1280258784485572611
# 4       1276561514456113152
# ...                     ...
# 123605  1150428788989161472
# 123606  1150245206135984128
# 123607  1149149581801693185
# 123608  1149149391145451520
# 123609  1148180844688756736
#
#                                             User_Mentions    User_Name
# 0                                                      []  @Trevornoah
# 1       [{'screen_name': 'KingBach', 'name': 'King Bac...  @Trevornoah
# 2                                                      []  @Trevornoah
# 3                                                      []  @Trevornoah
# 4       [{'screen_name': 'franklinleonard', 'name': 'F...  @Trevornoah
# ...                                                   ...          ...
# 123605                                                 []   @gettleman
# 123606  [{'screen_name': 'scroll_in', 'name': 'scroll....   @gettleman
# 123607                                                 []   @gettleman
# 123608  [{'screen_name': 'halbfinger', 'name': 'David ...   @gettleman
# 123609                                                 []   @gettleman
#
# [123610 rows x 9 columns]

# %% [markdown]
# ### Calculating the popularity score for the influencers

# %%
popular_influence = influencers_tweets[['User_Name','Favorite_count', 'Retweet_count']]
popularity = popular_influence.groupby('User_Name', as_index=False)
popularity

# %%
new_popular_influencers = popularity.agg(np.sum)
new_popular_influencers['popularity_score'] = new_popular_influencers['Favorite_count'] + new_popular_influencers['Retweet_count'] 
new_popular_influencers = new_popular_influencers.sort_values('popularity_score', ascending=False).reset_index(drop=True)
new_popular_influencers
# Out:
#            User_Name  Favorite_count  Retweet_count  popularity_score
# 0       @malonebarry          339494       10828425          11167919
# 1   @MbuyiseniNdlozi         1160597        9018169          10178766
# 2        @Trevornoah         2365051        6541053           8906104
# 3   @Julius_S_Malema         1229048        5297624           6526672
# 4      @andiMakinana           71583        2539312           2610895
# ..               ...             ...            ...               ...
# 76       @KahnMorbee             502            152               654
# 77  @Entrepreneur_SA              33            231               264
# 78         @jaxpanik              17            144               161
# 79   @InvestInAfrica              26             28                54
# 80    @rangerdiaries               7              4                11
#
# [81 rows x 4 columns]

# %% [markdown]
# ### Chart showing the top 10 influencers by popularity score

# %%
top_10_influencers_popular = new_popular_influencers[:10]
top_10_influencers_popular
with sns.axes_style("whitegrid"):
    ax = sns.barplot(x='User_Name', y='popularity_score', data=top_10_influencers_popular)
ax.yaxis.set_major_formatter(mticker.ScalarFormatter())
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
plt.xticks(rotation=90)
plt.title('Top 10 african influencers according to their popularity score')
plt.xlabel('African Influencers')
plt.ylabel('Popularity Score')
plt.savefig('popularity_score_influencers.png', bbox_inches="tight", dpi=300)
